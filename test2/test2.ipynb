# %%
e <- read.csv("sta.csv")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mean(e$Food)
# Out:
# [1] 52.99333

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
t.test(e$Clothes~e$Sex,var.equal=TRUE)
# Out:
# 	Two Sample t-test
#
# data:  e$Clothes by e$Sex
# t = 5.4777, df = 148, p-value = 1.806e-07
# alternative hypothesis: true difference in means between group Female and group Male is not equal to 0
# 95 percent confidence interval:
#   7.429324 15.814905
# sample estimates:
# mean in group Female   mean in group Male
#             59.44928             47.82716

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
var.test(e$Food~e$Sex)
# Out:
# 	F test to compare two variances
#
# data:  e$Food by e$Sex
# F = 1.1215, num df = 68, denom df = 80, p-value = 0.6194
# alternative hypothesis: true ratio of variances is not equal to 1
# 95 percent confidence interval:
#  0.7105067 1.7856120
# sample estimates:
# ratio of variances
#           1.121469

# %%
1/1.121469
# Out:
# [1] 0.8916876

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sd(e$Entertainment)
# Out:
# [1] 9.03659

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
names(e)
# Out:
#  [1] "No."           "Sex"           "Year"          "Food"
#  [5] "Clothes"       "Entertainment" "X"             "X.1"
#  [9] "X.2"           "X.3"

# %%
cor(e$Food,e$Entertainment)
# Out:
# [1] 0.01303665

# %%
cor(e$Food,e$Clothes)
# Out:
# [1] 0.09000712

# %%
cor(e$Entertainment,e$Clothes)
# Out:
# [1] -0.2744552

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
IQR(e$Clothes)
# Out:
# [1] 20

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
var.test(e$Food,e$Entertainment)
# Out:
# 	F test to compare two variances
#
# data:  e$Food and e$Entertainment
# F = 2.3559, num df = 149, denom df = 149, p-value = 2.68e-07
# alternative hypothesis: true ratio of variances is not equal to 1
# 95 percent confidence interval:
#  1.706692 3.252054
# sample estimates:
# ratio of variances
#           2.355898

# %%
t.test(e$Entertainment,e$Food,var.equal=FALSE)
# Out:
# 	Welch Two Sample t-test
#
# data:  e$Entertainment and e$Food
# t = 0.35019, df = 256.18, p-value = 0.7265
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.188421  3.135088
# sample estimates:
# mean of x mean of y
#  53.46667  52.99333

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
t.test(e$Food~e$Sex,var.equal=FALSE)
# Out:
# 	Welch Two Sample t-test
#
# data:  e$Food by e$Sex
# t = 0.65078, df = 141.26, p-value = 0.5162
# alternative hypothesis: true difference in means between group Female and group Male is not equal to 0
# 95 percent confidence interval:
#  -3.033065  6.009984
# sample estimates:
# mean in group Female   mean in group Male
#             53.79710             52.30864

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
var.test(e$Food,e$Entertainment)
# Out:
# 	F test to compare two variances
#
# data:  e$Food and e$Entertainment
# F = 2.3559, num df = 149, denom df = 149, p-value = 2.68e-07
# alternative hypothesis: true ratio of variances is not equal to 1
# 95 percent confidence interval:
#  1.706692 3.252054
# sample estimates:
# ratio of variances
#           2.355898

# %%
t.test(e$Entertainment,e$Food,var.equal=FALSE)
# Out:
# 	Welch Two Sample t-test
#
# data:  e$Entertainment and e$Food
# t = 0.35019, df = 256.18, p-value = 0.7265
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.188421  3.135088
# sample estimates:
# mean of x mean of y
#  53.46667  52.99333
