# %%
Data <- readRDS("Data_for_Test_R.rds")
x1<-Data$x1
x2<-Data$x2
x3<-Data$x3
f1<-Data$f1
f2<-Data$f2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
summary(aov(x1~f1*f2))
# Out:
#             Df Sum Sq Mean Sq F value Pr(>F)
# f1           3 2336.7   778.9 243.030 <2e-16 ***
# f2           1   18.3    18.3   5.722 0.0204 *
# f1:f2        3    4.3     1.4   0.444 0.7226
# Residuals   52  166.7     3.2
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m1 <- mean(x1)
ms1 <- var(x1)*(length(x1)-1)/length(x1)
prod(dnorm(x1,m1,sqrt(ms1)))
# Out:
# [1] 1.982927e-86

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
t.test(x1, mu=24, alternative = "two.sided")
# Out:
# 	One Sample t-test
#
# data:  x1
# t = -3.5515, df = 59, p-value = 0.0007604
# alternative hypothesis: true mean is not equal to 24
# 95 percent confidence interval:
#  19.30971 22.69029
# sample estimates:
# mean of x
#        21

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
quantile(x2,0.2)
# Out:
#  20%
# 19.8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# C

# %%
cor.test(x1,x2)
# Out:
# 	Pearson's product-moment correlation
#
# data:  x1 and x2
# t = -0.4044, df = 58, p-value = 0.6874
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.3028726  0.2036407
# sample estimates:
#         cor
# -0.05302595

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mean(x3)+qt(0.95,59)*sd(x3)/sqrt(60)
# Out:
# [1] 27.79688

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A

# %%
t.test(x1,x2,mu=0,alternative="two.sided",var.equal=FALSE)
# Out:
# 	Welch Two Sample t-test
#
# data:  x1 and x2
# t = -4.5334, df = 117.83, p-value = 1.403e-05
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -7.639129 -2.994204
# sample estimates:
# mean of x mean of y
#  21.00000  26.31667

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
summary(aov(x3~f1))
# Out:
#             Df Sum Sq Mean Sq F value Pr(>F)
# f1           3     74   24.64   0.297  0.828
# Residuals   56   4649   83.02

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
var.test(x2,x3,alternative="two.sided")
# Out:
# 	F test to compare two variances
#
# data:  x2 and x3
# F = 0.49609, num df = 59, denom df = 59, p-value = 0.007948
# alternative hypothesis: true ratio of variances is not equal to 1
# 95 percent confidence interval:
#  0.2963246 0.8305142
# sample estimates:
# ratio of variances
#          0.4960865

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# C

# %%
t.test(x2,mu=25,alternative="greater")
# Out:
# 	One Sample t-test
#
# data:  x2
# t = 1.6184, df = 59, p-value = 0.05545
# alternative hypothesis: true mean is greater than 25
# 95 percent confidence interval:
#  24.95715      Inf
# sample estimates:
# mean of x
#  26.31667
